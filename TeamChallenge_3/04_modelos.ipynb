# %% [markdown]
# # Comparación con test

# %% [markdown]
# # Carga de librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from pprint import pprint

import warnings
warnings.filterwarnings('ignore')
pd.option_context('mode.use_inf_as_na', True)


import joblib
import os

from sklearn.decomposition import PCA


from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRFRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Cargo datos train

# %%
df_train = pd.read_csv('./data/df_final_precios_ordenadores.csv', index_col=0)
df_train.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'OpSys', 'Weight',
#        'Price_euros', 'Resolution_disc', 'Pantalla_disc', 'Family_disc',
#        'Clock_speed_disc', 'Modelo_procesador_disc', 'Gpu Type',
#        'Gpu_Brand_disc', 'GPU_model_disc', 'storage_type_disc'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (912, 16)

# %%
df_train.head(8)
# Out:
#       Company            TypeName  Inches  Ram       OpSys  Weight  \
# id
# 268      Dell            Notebook    15.6    8  Windows 10    2.36
# 347      Asus            Notebook    15.6    4  Windows 10    2.00
# 353   Toshiba            Notebook    13.3    8   Windows 7    1.20
# 578      Dell              Gaming    15.6   16  Windows 10    4.42
# 42       Dell           Ultrabook    12.5    8   Windows 7    1.26
# 867      Asus  2 in 1 Convertible    15.6   12  Windows 10    2.26
# 1136     Asus            Notebook    15.6    4       Linux    2.00
# 609       MSI              Gaming    15.6    8  Windows 10    2.40
#
#       Price_euros  Resolution_disc  Pantalla_disc  Family_disc  \
# id
# 268        749.00                0              1            3
# 347        449.00                0              1            0
# 353       1460.00                3              1            2
# 578       2868.99                9              4            3
# 42        1713.37                3              1            2
# 867       1099.00                3              1            3
# 1136       415.00                3              1            1
# 609       1142.80                3              1            3
#
#       Clock_speed_disc  Modelo_procesador_disc   Gpu Type  Gpu_Brand_disc  \
# id
# 268                  4                       4  Dedicated               0
# 347                  0                       0    Unknown               1
# 353                  3                       3    Unknown               1
# 578                  6                       6  Dedicated               2
# 42                   1                       4    Unknown               1
# 867                  4                       4  Dedicated               2
# 1136                 0                       0    Unknown               1
# 609                  6                       6  Dedicated               2
#
#       GPU_model_disc  storage_type_disc
# id
# 268                2                  1
# 347                0                  1
# 353                2                  3
# 578               10                  3
# 42                 2                  3
# 867                3                  3
# 1136               2                  3
# 609                3                  3

# %% [markdown]
# # Cargo datos test

# %%
df_test = pd.read_csv('./data/df_test_disc_precios_ordenadores.csv',index_col=0)
df_test.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'OpSys', 'Weight',
#        'Resolution_disc', 'Pantalla_disc', 'Family_disc', 'Clock_speed_disc',
#        'Modelo_procesador_disc', 'Gpu Type', 'Gpu_Brand_disc',
#        'GPU_model_disc', 'storage_type_disc'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (391, 15)

# %%
df_test.head(8)
# Out:
#      Company            TypeName  Inches  Ram       OpSys  Weight  \
# id
# 181       HP           Ultrabook    13.3   16  Windows 10    1.30
# 708     Acer            Notebook    15.6    8  Windows 10    2.20
# 862     Acer            Notebook    15.6    4       Linux    2.40
# 1064      HP            Notebook    14.0    8   Windows 7    1.43
# 702       HP            Notebook    13.3    8  Windows 10    1.34
# 585     Dell  2 in 1 Convertible    15.6   16  Windows 10    2.00
# 195    Razer              Gaming    14.0   16  Windows 10    1.95
# 463     Asus            Notebook    15.6    4       Linux    2.10
#
#       Resolution_disc  Pantalla_disc  Family_disc  Clock_speed_disc  \
# id
# 181               9.0              4          3.0               4.0
# 708               0.0              1          2.0               4.0
# 862               0.0              1          1.0               0.0
# 1064              3.0              1          2.0               3.0
# 702               3.0              1          2.0               2.0
# 585               3.0              1          3.0               3.0
# 195               3.0              1          3.0               6.0
# 463               3.0              1          2.0               2.0
#
#       Modelo_procesador_disc   Gpu Type  Gpu_Brand_disc  GPU_model_disc  \
# id
# 181                      4.0    Unknown             1.0             2.0
# 708                      0.0  Dedicated             0.0             3.0
# 862                      0.0    Unknown             1.0             2.0
# 1064                     3.0    Unknown             1.0             2.0
# 702                      2.0    Unknown             1.0             2.0
# 585                      3.0    Unknown             1.0             2.0
# 195                      6.0  Dedicated             2.0             6.0
# 463                      2.0  Dedicated             2.0             3.0
#
#       storage_type_disc
# id
# 181                   3
# 708                   3
# 862                   1
# 1064                  3
# 702                   3
# 585                   3
# 195                   3
# 463                   1

# %% [markdown]
# Elimino la columna target Price_euros

# %%
X_train = df_train.drop(columns='Price_euros')
y_train = df_train['Price_euros']

# %%
features_list = X_train.columns.tolist()

df_test = df_test[features_list]

# %%
X_test = df_test

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
# Out:
# Las columnas son las mismas y están en el mismo orden: True

# %% [markdown]
# ## Cargo el modelo entrenado

# %%
#model_path = os.path.join('models', 'grid_search.pkl')
#grid_search_cat_scaled = joblib.load(model_path)

# %% [markdown]
# ## Comparo contra test

# %%
features_cat = X_train.select_dtypes(include='object').columns.tolist()

X_train = pd.get_dummies(X_train, features_cat, dtype=int)
X_test = pd.get_dummies(X_test,features_cat,dtype=int)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 268 to 1179
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Inches                       912 non-null    float64
#  1   Ram                          912 non-null    int64
#  2   Weight                       912 non-null    float64
#  3   Resolution_disc              912 non-null    int64
#  4   Pantalla_disc                912 non-null    int64
#  5   Family_disc                  912 non-null    int64
#  6   Clock_speed_disc             912 non-null    int64
#  7   Modelo_procesador_disc       912 non-null    int64
#  8   Gpu_Brand_disc               912 non-null    int64
#  9   GPU_model_disc               912 non-null    int64
#  10  storage_type_disc            912 non-null    int64
#  11  Company_Acer                 912 non-null    int32
#  12  Company_Apple                912 non-null    int32
#  13  Company_Asus                 912 non-null    int32
#  14  Company_Chuwi                912 non-null    int32
#  15  Company_Dell                 912 non-null    int32
#  16  Company_Fujitsu              912 non-null    int32
#  17  Company_Google               912 non-null    int32
#  18  Company_HP                   912 non-null    int32
#  19  Company_Huawei               912 non-null    int32
#  20  Company_LG                   912 non-null    int32
#  21  Company_Lenovo               912 non-null    int32
#  22  Company_MSI                  912 non-null    int32
#  23  Company_Mediacom             912 non-null    int32
#  24  Company_Microsoft            912 non-null    int32
#  25  Company_Razer                912 non-null    int32
#  26  Company_Samsung              912 non-null    int32
#  27  Company_Toshiba              912 non-null    int32
#  28  Company_Vero                 912 non-null    int32
#  29  Company_Xiaomi               912 non-null    int32
#  30  TypeName_2 in 1 Convertible  912 non-null    int32
#  31  TypeName_Gaming              912 non-null    int32
#  32  TypeName_Netbook             912 non-null    int32
#  33  TypeName_Notebook            912 non-null    int32
#  34  TypeName_Ultrabook           912 non-null    int32
#  35  TypeName_Workstation         912 non-null    int32
#  36  OpSys_Android                912 non-null    int32
#  37  OpSys_Chrome OS              912 non-null    int32
#  38  OpSys_Linux                  912 non-null    int32
#  39  OpSys_Mac OS X               912 non-null    int32
#  40  OpSys_No OS                  912 non-null    int32
#  41  OpSys_Windows 10             912 non-null    int32
#  42  OpSys_Windows 10 S           912 non-null    int32
#  43  OpSys_Windows 7              912 non-null    int32
#  44  OpSys_macOS                  912 non-null    int32
#  45  Gpu Type_Dedicated           912 non-null    int32
#  46  Gpu Type_Unknown             912 non-null    int32
# dtypes: float64(2), int32(36), int64(9)
# memory usage: 213.8 KB

# %%
X_train.shape
# Out:
# (912, 47)

# %%
X_test.shape
# Out:
# (391, 44)

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
if son_iguales == True:
    print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
else:
    col_diferentes = set(X_train)-set(X_test)
    print(col_diferentes)
# Out:
# {'OpSys_Android', 'Company_Fujitsu', 'Company_Mediacom'}

# %%
# Alineo las columnas añadiendo las faltantes con valor cero.
X_train, X_test = X_train.align(X_test, join='outer', axis=1, fill_value=0)

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
if son_iguales == True:
    print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
else:
    col_diferentes = set(X_train)-set(X_test)
    print(col_diferentes)
# Out:
# Las columnas son las mismas y están en el mismo orden: True

# %%
X_train.shape
# Out:
# (912, 47)

# %%
X_test.shape
# Out:
# (391, 47)

# %% [markdown]
# _____

# %% [markdown]
# He conseguido sacar la optimización del gbr_4

# %%
# Cargo el modelo entrenado
model_path = os.path.join('models', 'gbr_grid_4.pkl')
gbr_grid_4 = joblib.load(model_path)

# %%
features_selector = ['Inches', 'Ram', 'Weight', 'Resolution_disc', 'Pantalla_disc',
       'Family_disc', 'Clock_speed_disc', 'Modelo_procesador_disc',
       'Gpu_Brand_disc', 'GPU_model_disc', 'storage_type_disc',
       'Company_Asus', 'Company_Dell', 'Company_HP', 'Company_LG',
       'Company_Lenovo', 'Company_Razer', 'TypeName_2 in 1 Convertible',
       'TypeName_Gaming', 'TypeName_Notebook', 'TypeName_Ultrabook',
       'TypeName_Workstation', 'OpSys_Windows 10', 'OpSys_Windows 7']

# %%
X_train.shape
# Out:
# (912, 47)

# %%
X_test.shape
# Out:
# (391, 47)

# %% [markdown]
# Tengo que escalar las variables

# %%
features_scaled = X_train.select_dtypes(include=(['int','float'])).columns.tolist()

print(features_scaled)
scaler = StandardScaler()

temp_x_train = scaler.fit_transform(X_train[features_scaled])
X_train_scaled = X_train.copy()
X_train_scaled[features_scaled] = temp_x_train


temp_x_test = scaler.transform(X_test[features_scaled])
X_test_scaled = X_test.copy()
X_test_scaled[features_scaled] = temp_x_test
# Out:
# ['Clock_speed_disc', 'Company_Acer', 'Company_Apple', 'Company_Asus', 'Company_Chuwi', 'Company_Dell', 'Company_Fujitsu', 'Company_Google', 'Company_HP', 'Company_Huawei', 'Company_LG', 'Company_Lenovo', 'Company_MSI', 'Company_Mediacom', 'Company_Microsoft', 'Company_Razer', 'Company_Samsung', 'Company_Toshiba', 'Company_Vero', 'Company_Xiaomi', 'Family_disc', 'GPU_model_disc', 'Gpu Type_Dedicated', 'Gpu Type_Unknown', 'Gpu_Brand_disc', 'Inches', 'Modelo_procesador_disc', 'OpSys_Android', 'OpSys_Chrome OS', 'OpSys_Linux', 'OpSys_Mac OS X', 'OpSys_No OS', 'OpSys_Windows 10', 'OpSys_Windows 10 S', 'OpSys_Windows 7', 'OpSys_macOS', 'Pantalla_disc', 'Ram', 'Resolution_disc', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'Weight', 'storage_type_disc']

# %%
X_test_model_cat = X_test_scaled[features_selector]
y_predict_gbr_4 = gbr_grid_4.predict(X_test_model_cat)
y_predict_gbr_4
# Out:
# array([2181.24938015,  614.55984353,  366.68121221, 1456.92110932,
#        1091.488114  , 1397.09928079, 2948.1788443 ,  544.34991962,
#        1806.38035691, 1903.66753373, 1361.30802624,  528.78402288,
#         251.36585958,  644.68140578,  386.50982427, 1494.64688908,
#         381.55021999, 2134.34042511, 1662.96342311, 1543.59290887,
#        1326.21517609, 1372.55263567, 1849.13410473, 1377.226407  ,
#        1789.85543661,  386.81729298,  949.65896049,  315.46827836,
#        1068.58672599,  519.68966336,  982.74445763, 1193.45757691,
#        2001.88883118,  330.82216334,  650.9389389 , 1564.26657136,
#         821.49501938,  682.18749223, 3056.93662758,  620.4413043 ,
#         595.07883929,  990.73764162,  804.84081252, 1984.49188436,
#         892.05816533, 1682.92016967,  474.40201523, 3294.77160032,
#         286.90261984, 1263.24286345, 1109.24695943,  978.59179641,
#         916.27555565,  357.88873624, 1107.49077966,  780.25097311,
#         901.18839567,  254.07896334, 1616.89595179, 1057.09594706,
#        1286.80151541, 1246.07263257,  591.32862672, 1091.13994968,
#        1394.51933644, 1338.6641919 ,  549.318246  , 2587.82604098,
#         566.43919321, 2178.6686353 ,  952.1946649 , 2442.89657121,
#        1671.68202946, 1029.910302  , 1399.02229523, 1076.90272252,
#         953.19085324,  440.41308602, 1172.06987347, 1134.08391022,
#         284.75852634, 1488.11648459, 1208.39837391,  894.79059116,
#        1439.29744686, 1953.51154971, 2189.53885919,  409.23004594,
#        1894.99199925,  379.54529548,  827.15283164,  443.32916217,
#         279.77711454,  569.81325585, 1486.94652146,  578.9968979 ,
#         403.11014699, 1007.54987571,  681.96601944, 1177.91815903,
#        1375.23370776, 1778.72995414, 1811.29816375,  495.64969876,
#         883.10214566,  905.75787845, 1241.9063438 ,  400.59097114,
#         809.89422652, 1185.63528872,  934.19397479, 1582.82076978,
#         595.07883929, 1851.74514329, 1502.38491964, 1751.41447928,
#         600.36597592,  325.6744152 , 1078.31855137, 1220.30386797,
#         775.32231147,  180.69826176,  390.36785051,  768.92468909,
#        1798.30679421, 1811.29816375, 2707.45253005, 1191.60848535,
#        1694.6973645 , 1150.27904536, 2107.49378075, 1944.1356635 ,
#         742.51236576, 1514.61825481, 1669.2696751 ,  325.6744152 ,
#         557.72218612,  365.48091178,  916.27555565,  278.90474153,
#         862.47191787,  295.48931732,  637.21448776,  698.07026081,
#        1749.11869159, 1184.59848447,  407.95764583,  907.03858019,
#         532.38061622, 2304.4493034 ,  115.380636  , 1256.4129627 ,
#         802.95644606, 1048.84935678,  706.86432595, 1181.87897876,
#        1431.83244429, 1288.56810104, 1023.17757617, 1165.79046201,
#         442.75312224, 2005.58612655, 1237.91120866,  553.64630443,
#         779.7306967 , 1705.08949983,  549.96155749, 1578.87657941,
#         178.0513416 , 2530.97235562,  506.90545201, 1948.95736559,
#        1235.75743248,  758.35401204,  736.50546879, 1483.49969176,
#         698.2362317 ,  456.36621448,  474.31496008, 1266.00757102,
#         779.7306967 ,  984.26054005,  336.66864801, 1347.29485507,
#         873.02397529,  553.64630443,  751.76628492,  993.70801111,
#        1164.08900657,  335.68913765, 1133.71043105,  326.04116573,
#        1953.13141187,  571.97231162,  973.6727071 , 1253.64727684,
#         541.84501588,  699.98359725, 1625.52930183])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample= pd.read_csv('./data/sample_submission.csv')
sample.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample['id'] = X_test_scaled.index
sample['Price_euros'] = y_predict_gbr_4.round(2)

# %%
sample
# Out:
#        id  Price_euros
# 0     181      2181.25
# 1     708       614.56
# 2     862       366.68
# 3    1064      1456.92
# 4     702      1091.49
# ..    ...          ...
# 386  1281       973.67
# 387   524      1253.65
# 388  1015       541.85
# 389  1236       699.98
# 390  1036      1625.53
#
# [391 rows x 2 columns]

# %%
sample.to_csv('./data/submission_gbr_4.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 chequeator(sample)
#
# Cell In[35], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined

# %% [markdown]
# ___

# %%
X_train_model = X_train_scaled[features_selector]

gb= GradientBoostingRegressor(max_depth=5, random_state=42)

param_grid_gb_reg = {
    'n_estimators': [100, 200,300],
    'max_depth': [5,6,7],
    'learning_rate': [0.08, 0.1,0.2],
    'subsample': [0.2, 0.5, 1.0]
    
}

gbr_grid = GridSearchCV(estimator=gb,
                     param_grid=param_grid_gb_reg, 
                     scoring='neg_mean_absolute_error', 
                     cv=5, 
                     n_jobs=-1)

gbr_grid.fit(X_train_model, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingRegressor(max_depth=5, random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.08, 0.1, 0.2],
#                          'max_depth': [5, 6, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.2, 0.5, 1.0]},
#              scoring='neg_mean_absolute_error')

# %%
best_model_gb_reg = gbr_grid.best_estimator_
best_params_gb_reg = gbr_grid.best_params_
best_score_gb_reg = gbr_grid.best_score_

print(f'Best Parameters for Regression: {best_params_gb_reg}')
print(f'Best Score for Regression: {best_score_gb_reg}')
# Out:
# Best Parameters for Regression: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.5}
# Best Score for Regression: -163.4830373325415

# %%
X_test_model_cat = X_test_scaled[features_selector]
y_predict_gbr = gbr_grid.predict(X_test_model_cat)
y_predict_gbr
# Out:
# array([1953.96155957,  680.40443031,  330.87811478, 1461.21441152,
#        1224.29997146, 1382.58331509, 3084.37137331,  609.59335424,
#        2125.86873998, 2055.64839155, 1443.12419777,  539.52699939,
#         262.56292379,  706.8089067 ,  372.3468642 , 1492.02945039,
#         376.72190271, 2050.12903531, 1635.48839843, 1583.34119704,
#        1555.71350559, 1444.26477484, 1754.46155536, 1474.97068251,
#        1807.48169323,  392.60862927,  952.89596923,  308.5227573 ,
#        1087.32622896,  514.91912539,  975.48975527, 1176.12224581,
#        2017.40280012,  307.65620598,  657.03746402, 1531.63214134,
#         817.146441  ,  626.36104517, 3121.45287572,  625.6517889 ,
#         598.03836972,  933.48336684,  841.63615082, 1938.22531734,
#         937.69219971, 1682.86901336,  454.21292599, 3189.38156395,
#         308.8425973 , 1336.222141  , 1135.16672874,  949.05656358,
#         938.58442419,  345.43788186, 1085.66853691,  774.32990871,
#         866.87537493,  259.16956199, 1653.86872122, 1103.5027059 ,
#        1313.1138139 , 1278.16937381,  636.10455766, 1157.67223701,
#        1482.63168973, 1419.71840454,  533.55584967, 2738.0809235 ,
#         754.86285287,  943.20138925, 1149.17231299, 1075.64973463,
#        1066.86607352,  687.14258958,  582.15886746,  638.74379907,
#        1821.57033391,  933.08853627, 1524.91698766, 1735.86222249,
#        1102.41996053, 1788.76463182,  788.20034642,  491.03825892,
#        1787.70330688, 1349.0733758 ,  915.07766231,  481.77504499,
#         958.25868734,  554.5332991 , 2404.69736965,  568.9797516 ,
#        1340.75815442, 1178.31720616,  785.69758992,  515.9831632 ,
#         307.71009842,  558.45916917, 1527.80730654,  566.4818148 ,
#         553.96802943, 1105.32148926,  698.82291328, 1352.11163051,
#        1336.87352937, 1998.16678815, 1887.53282735,  495.93760512,
#         879.4530157 ,  945.47549541, 1185.44698733,  528.07591172,
#         767.7921363 ,  987.26041535,  893.09940981, 1562.94440387,
#         598.03836972, 2033.54982373, 1623.52633029, 1509.80350317,
#         552.61388681,  303.9319551 ,  957.67794416, 1421.76795959,
#         777.47171343,  212.66968657,  423.02276417,  755.66568548,
#        1756.35205511, 1887.53282735, 2654.07356631, 1123.03657972,
#        1699.01657635, 1245.51949196, 2094.51448499, 1984.54300279,
#         792.28967406, 1563.99249813, 1567.90513675,  303.9319551 ,
#         604.80394334,  396.57641642,  938.58442419,  305.73281868,
#         886.96321713,  296.92556933,  618.66941658,  637.69143913,
#        1594.81812293, 1211.76543585,  350.65273215,  887.0465856 ,
#         615.23280278, 1981.50530447,   66.07102507, 1298.89402431,
#         741.3424291 , 1105.10571838,  704.49930196, 1165.31878083,
#        1435.78710654, 1245.0940561 , 1021.72751548, 1195.57142501,
#         467.81961236, 1891.00181201, 1252.78176425,  520.21758949,
#         766.09020121, 1640.25464238,  532.64351555, 1538.54489295,
#         190.20529289, 2085.00508645,  490.47555256, 1908.8542077 ,
#        1249.00297597,  692.85502432,  701.77637142, 1602.41366046,
#         620.53050926,  478.85172752,  475.31251797, 1102.18229536,
#         766.09020121,  937.86967025,  306.49621095, 1374.70560822,
#         922.6745905 ,  520.21758949,  734.41259489, 1093.06260269,
#        1159.62933492,  332.78211666, 1100.43579194,  318.31764324,
#        2190.40746033,  580.1602652 ,  878.08968243, 1412.55570211,
#         511.94276482,  572.02911608, 1655.99262629])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample= pd.read_csv('./data/sample_submission.csv')
sample.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample['id'] = X_test_scaled.index
sample['Price_euros'] = y_predict_gbr.round(2)

# %%
sample
# Out:
#        id  Price_euros
# 0     181      1953.96
# 1     708       680.40
# 2     862       330.88
# 3    1064      1461.21
# 4     702      1224.30
# ..    ...          ...
# 386  1281       878.09
# 387   524      1412.56
# 388  1015       511.94
# 389  1236       572.03
# 390  1036      1655.99
#
# [391 rows x 2 columns]

# %%
sample.to_csv('./data/submission_gbr.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 chequeator(sample)
#
# Cell In[60], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined

# %% [markdown]
# ___

# %% [markdown]
# Pruebo con PCA (Análisis de Componenetes Principales)

# %%
pca_cl = PCA()

pca_cl.fit(X_train_scaled)

X_train_pca = pca_cl.transform(X_train_scaled)

# %%
X_train_pca.shape
# Out:
# (912, 47)

# %%
df_pca = pd.DataFrame(
    data = pca_cl.components_,
    columns=X_train_scaled.columns,
    index=[f'PC{n}' for n in range(1,X_train_scaled.shape[1]+1)]
)

df_pca
# Out:
#       Clock_speed_disc  Company_Acer  Company_Apple  Company_Asus  \
# PC1       2.954171e-01     -0.063326       0.022865      0.025737
# PC2       7.134466e-02     -0.084461       0.285703     -0.069313
# PC3      -1.677133e-02      0.074688       0.427729     -0.039017
# PC4       2.832158e-02      0.027320      -0.119168      0.047279
# PC5       5.612465e-02      0.213664       0.065768      0.161400
# PC6       6.538733e-02     -0.123371      -0.185307     -0.234155
# PC7       9.129614e-02      0.146538      -0.227628     -0.099576
# PC8      -6.944936e-02      0.000879      -0.040338      0.055161
# PC9       1.342503e-02     -0.042473      -0.072295      0.060898
# PC10     -7.501384e-02      0.248196      -0.097431     -0.197308
# PC11     -4.145220e-02     -0.190375      -0.026906     -0.013684
# PC12     -7.195363e-02     -0.159431      -0.156011      0.515476
# PC13     -3.119053e-02     -0.149953       0.037022      0.496927
# PC14     -1.307850e-02     -0.446700      -0.018277     -0.203894
# PC15     -5.493326e-03      0.004016       0.003597     -0.166514
# PC16     -8.438486e-02      0.369525       0.009648     -0.104114
# PC17     -2.541398e-02      0.162468      -0.027405     -0.148639
# PC18     -2.906478e-03      0.132469      -0.031126     -0.015773
# PC19     -3.061042e-02     -0.052079       0.015398      0.064114
# PC20      4.765241e-02      0.032388      -0.005157     -0.024211
# PC21      8.523493e-03      0.007960       0.003215     -0.032837
# PC22     -1.927078e-02     -0.007865       0.000714      0.007768
# PC23      5.551772e-03     -0.044818       0.005542     -0.026865
# PC24     -1.787343e-02     -0.289827       0.032412      0.048759


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 8))
ax.plot(
    np.arange(len(X_train_scaled.columns)) + 1,
    prop_varianza_acum,
    marker = 'o'
)

for x, y in zip(np.arange(len(X_train_scaled.columns)) + 1, prop_varianza_acum):
    label = round(y, 2)
    ax.annotate(
        label,
        (x,y),
        textcoords="offset points",
        xytext=(0,10),
        ha='center'
    )
    
ax.set_ylim(0, 1.1)
ax.set_xticks(np.arange(pca_cl.n_components_) + 1)
ax.set_title('Porcentaje de varianza explicada acumulada')
ax.set_xlabel('Componente principal')
ax.set_ylabel('Por. varianza acumulada');
# Out:
# ------------------------------------------
# Porcentaje de varianza explicada acumulada
# ------------------------------------------
# [0.14112835 0.22102668 0.27011547 0.31185378 0.34990207 0.38642906
#  0.42009672 0.45246483 0.48012061 0.50737678 0.53374555 0.55792198
#  0.58168165 0.60485204 0.62760745 0.65016132 0.67205892 0.69384554
#  0.71549525 0.73691983 0.75826479 0.77959777 0.80035839 0.82046526
#  0.83923041 0.8567332  0.87365051 0.8896091  0.9053648  0.91998682
#  0.93262968 0.94407084 0.9548254  0.96467498 0.97199974 0.97832039
#  0.98423482 0.98912133 0.99329879 0.99607484 0.9981565  1.
#  1.         1.         1.         1.         1.        ]

# %%
rf_pca = RandomForestRegressor (max_depth=5, random_state=42) 
scores_pca = []
for num_PCs in range(5,10):
    print(f"Probando con {num_PCs} componentes:", sep = " ")
    X_train_pca_reduced = X_train_pca[:,:num_PCs]# Array de numpy. Al estar ordenadas me quedo con las que quiero.
    score_pca = np.mean(cross_val_score(rf_pca, X_train_pca_reduced, y_train, cv = 5, scoring = "neg_mean_absolute_error"))
    print(score_pca)
    scores_pca.append(score_pca)
# Out:
# Probando con 5 componentes:
# -205.01144421907026
# Probando con 6 componentes:
# -202.74230179663726
# Probando con 7 componentes:
# -202.68706063727404
# Probando con 8 componentes:
# -202.18122446731007
# Probando con 9 componentes:
# -202.84314054565

# %%
rf_pca = RandomForestRegressor (max_depth=5, random_state=42) 
scores_pca = []
for num_PCs in range(38,46):
    print(f"Probando con {num_PCs} componentes:", sep = " ")
    X_train_pca_reduced = X_train_pca[:,:num_PCs]# Array de numpy. Al estar ordenadas me quedo con las que quiero.
    score_pca = np.mean(cross_val_score(rf_pca, X_train_pca_reduced, y_train, cv = 5, scoring = "neg_mean_absolute_error"))
    print(score_pca)
    scores_pca.append(score_pca)
# Out:
# Probando con 38 componentes:
# -196.22529335107453
# Probando con 39 componentes:
# -196.98553754516942
# Probando con 40 componentes:
# -196.87883573959718
# Probando con 41 componentes:
# -195.6867958931843
# Probando con 42 componentes:
# -196.04118831956694
# Probando con 43 componentes:
# -196.08917799299496
# Probando con 44 componentes:
# -195.99207253081607
# Probando con 45 componentes:
# -196.0277989861095

# %% [markdown]
# Pues aparentemente no mejoro los otros modelos

# %% [markdown]
# ___

# %%
X_train_model = X_train_scaled

gb= GradientBoostingRegressor(max_depth=5, random_state=42)

param_grid_gb_reg = {
    'n_estimators': [100, 200,300],
    'max_depth': [6,7,8],
    'learning_rate': [0.07,0.08, 0.09],
    'subsample': [0.2, 0.5, 1.0]
    
}

gbr_grid_all = GridSearchCV(estimator=gb,
                     param_grid=param_grid_gb_reg, 
                     scoring='neg_mean_absolute_error', 
                     cv=5, 
                     n_jobs=-1)

gbr_grid_all.fit(X_train_model, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingRegressor(max_depth=5, random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.07, 0.08, 0.09],
#                          'max_depth': [6, 7, 8],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.2, 0.5, 1.0]},
#              scoring='neg_mean_absolute_error')

# %%
best_model_gb_reg = gbr_grid_all.best_estimator_
best_params_gb_reg = gbr_grid_all.best_params_
best_score_gb_reg = gbr_grid_all.best_score_

print(f'Best Parameters for Regression: {best_params_gb_reg}')
print(f'Best Score for Regression: {best_score_gb_reg}')
# Out:
# Best Parameters for Regression: {'learning_rate': 0.08, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.5}
# Best Score for Regression: -158.06755669177548

# %% [markdown]
# Overfitting: luego a la hora de picarlo en Kaggle se va a 174€ el error

# %%
y_predict_gbr_all = gbr_grid_all.predict(X_test_scaled)
y_predict_gbr_all
# Out:
# array([2015.40141864,  589.54316697,  370.8093447 , 1425.91268129,
#        1058.82922029, 1297.55001043, 3088.64231585,  628.53796948,
#        2051.05462029, 2158.07221924, 1445.47075529,  557.20417132,
#         271.75434007,  716.17874077,  396.88770411, 1495.59586989,
#         299.38838211, 2045.77482369, 1687.1244533 , 1582.80317655,
#        1518.35436799, 1406.26537821, 1744.09141338, 1474.02577092,
#        1764.15991319,  373.2508458 ,  998.63722918,  310.97837104,
#        1143.67769515,  516.12942277,  964.59758402, 1335.56679557,
#        2002.1627439 ,  304.11595401,  665.74226015, 1557.05658192,
#         823.43284286,  620.42646791, 3134.43292   ,  629.98358721,
#         705.04070702,  965.09283348,  949.52918572, 1915.54332151,
#         896.03681442, 1704.44442429,  471.48906144, 3033.48897477,
#         301.2962905 , 1349.023554  , 1163.21881342,  930.8330754 ,
#         941.94826327,  315.91068587, 1210.63484312,  746.06689757,
#         918.86434731,  231.82274434, 1538.97620926, 1080.28832714,
#        1365.40301237, 1280.13935212,  642.342102  , 1197.97720375,
#        1408.69253004, 1414.40391938,  556.40821092, 2679.15145011,
#         561.61489157, 2105.9337081 ,  956.65733896, 2435.1659149 ,
#        1705.63146876, 1119.79862099, 1428.83742764, 1126.95221752,
#         988.00436495,  469.46736765, 1198.41897374, 1140.21329059,
#         330.51521593, 1513.46393658, 1208.14484171,  971.45927378,
#        1364.41455302, 1773.81824986, 2116.12775701,  494.07991693,
#        1925.22073603,  412.8211481 ,  855.46545853,  428.70650443,
#        1080.28832714,  981.31241614, 1940.52937619,  565.82293038,
#        1917.86200488,  949.85839837,  993.34509178,  676.96295157,
#         563.67855681,  439.52071145, 1390.32091253, 1122.81392241,
#         861.75533063,  738.66509067, 1034.28019948,  797.18547717,
#        1275.37072819, 1441.11998393, 1362.66617795,  925.39685212,
#         319.85558511,  564.78045892, 1026.49045769, 1500.07601816,
#         922.35387976, 1240.42448288,  677.82505365, 1503.35583346,
#         432.32953926, 1243.73261047,  907.47677031, 1380.16272168,
#         331.38580045, 1463.78051201, 2618.71092569, 1941.82794821,
#        1915.54332151,  951.49179665, 1142.07661386, 1338.68471579,
#         444.19609366, 1669.26454601,  685.69087935,  610.58210388,
#         221.58956102, 2124.74537467, 1289.10953253,  642.65620346,
#         583.28373621,  381.68116653,  941.94826327,  280.15317303,
#         902.31857213,  278.39174766,  607.03168419,  672.26027399,
#        1729.53497595, 1245.53080982,  316.31959531, 1022.48582586,
#         572.48953313, 1941.28693939,  110.43614638, 1267.19446543,
#         692.31297954, 1197.4558106 ,  680.20894004, 1197.50856884,
#        1383.01138806, 1336.00726386, 1006.81916774, 1159.87481535,
#         459.00740653, 1945.82787355, 1277.6553258 ,  508.93448674,
#         699.62750557, 1674.10525007,  506.68175861, 1527.61317427,
#         169.51744205, 2022.19408818,  459.6032605 , 1791.76332515,
#        1237.96566818,  685.24167968,  700.77395346, 1466.28448023,
#         690.2202177 ,  444.18978235,  474.93937181, 1083.93155994,
#         699.62750557,  984.25651507,  296.42242083, 1442.77015445,
#        1050.90884454,  508.93448674,  756.61005727, 1138.42203748,
#        1168.73556926,  327.82988468, 1110.93708787,  322.07813355,
#        2244.88370692,  557.52309857,  960.28833216, 1330.79834721,
#         467.75311961,  608.54981404, 1709.18108036])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample= pd.read_csv('./data/sample_submission.csv')
sample.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample['id'] = X_test_scaled.index
sample['Price_euros'] = y_predict_gbr_all.round(2)

# %%
sample
# Out:
#        id  Price_euros
# 0     181      2015.40
# 1     708       589.54
# 2     862       370.81
# 3    1064      1425.91
# 4     702      1058.83
# ..    ...          ...
# 386  1281       960.29
# 387   524      1330.80
# 388  1015       467.75
# 389  1236       608.55
# 390  1036      1709.18
#
# [391 rows x 2 columns]

# %%
sample.to_csv('./data/submission_gbr_all.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 chequeator(sample)
#
# Cell In[100], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined

# %% [markdown]
# ___

# %% [markdown]
# Voy a probar el CatBoost con más variables que de primeras ha dado buen resultado en el cross_val_score

# %%
selector_model_plus =['Inches', 'Ram', 'Weight', 'Resolution_disc', 'Pantalla_disc',
       'Family_disc', 'Clock_speed_disc', 'Modelo_procesador_disc',
       'Gpu_Brand_disc', 'GPU_model_disc', 'storage_type_disc',
       'Company_Asus', 'Company_Dell', 'Company_HP', 'Company_Lenovo',
       'Company_MSI', 'Company_Razer', 'TypeName_Gaming',
       'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation',
       'OpSys_No OS', 'OpSys_Windows 10', 'OpSys_Windows 7']

# %%
cat = CatBoostRegressor(depth=6, random_state=42,verbose=0)

X_train_model = X_train[selector_model_plus]

param_grid = {
    'depth': [6, 7,8],
    'learning_rate': [0.03,0.05,0.06],
    'iterations': [1300,1400,1500]
}

# Instanciamos GridSearchCV
cat_grid = GridSearchCV(estimator=cat,
                           param_grid=param_grid,
                           scoring='neg_mean_absolute_error',
                           cv=5,
                           verbose=0)

# Ejecutamos el ajuste de hiperparámetros
cat_grid.fit(X_train_model, y_train)

# Imprimimos los mejores parámetros encontrados
print(f'Mejores hiperparámetros: {cat_grid.best_params_}')
print(f'Mejor MAE: {cat_grid.best_score_}')
# Out:
# Mejores hiperparámetros: {'depth': 7, 'iterations': 1300, 'learning_rate': 0.05}
# Mejor MAE: -156.98858352221058

# %%
import joblib
import os

model_path = os.path.join('models', 'cat_grid.pkl')
joblib.dump(cat_grid, model_path)
# Out:
# ['models\\cat_grid.pkl']

# %%
y_predict_cat_plus = cat_grid.predict(X_test)
y_predict_cat_plus
# Out:
# array([2133.40272484,  810.67894457,  344.83589186, 1464.69409544,
#        1158.64419268, 1366.15080473, 3049.58240801,  566.84440122,
#        1781.93811542, 2244.65850382, 1424.50770821,  518.74958805,
#         259.61036321,  684.53642152,  427.28756378, 1443.56049461,
#         319.75145672, 2061.51239328, 1644.35178473, 1488.036824  ,
#        1515.40646127, 1311.56656004, 1761.66972553, 1414.83978608,
#        1781.25412147,  594.00628234,  917.3442165 ,  327.05845144,
#        1134.2283925 ,  530.18828858,  965.84167292, 1199.63796475,
#        2017.82709381,  327.96053142,  645.85355442, 1511.59063482,
#         795.98573861,  619.3848214 , 3162.53589822,  730.35060895,
#         596.95245545,  912.24901359,  982.07604616, 1946.62682977,
#         904.08871028, 1756.65619822,  517.75360852, 2901.58592447,
#         319.54765808, 1338.18814905, 1119.68908584,  927.82491685,
#         947.59245344,  326.81562344, 1050.02847779,  699.56919486,
#         742.2691088 ,  245.04882237, 1578.57832352, 1102.13128088,
#        1395.20102309, 1165.34193891,  577.57306433, 1176.32137313,
#        1386.80711602, 1353.71206568,  523.20330122, 2682.73907123,
#         560.14748198, 2127.96544814,  951.46908808, 2630.95030714,
#        1590.72138553, 1140.75307071, 1412.0953377 , 1152.27536684,
#         985.24111253,  455.67588607, 1131.24754113, 1170.49735428,
#         291.89103911, 1638.75141636, 1218.31923882,  958.5860217 ,
#        1262.44703589, 1668.66690365, 2168.47298446,  447.89349945,
#         940.95020368,  550.12875919, 2582.30402228,  524.50818197,
#        1389.87688569, 1257.63996672,  860.49288468,  579.6495705 ,
#         286.92574308,  559.80215791, 1521.1478107 ,  545.24069401,
#         498.3979407 , 1171.00500705,  722.66305175, 1324.20135076,
#        1335.1081042 , 2118.74449979, 1912.86929868,  493.5567612 ,
#         928.84305171,  861.31759116, 1319.06669612,  539.39495597,
#         821.58761749, 1076.12936428,  917.10961776, 1468.65798813,
#         596.95245545, 1983.51110907, 1629.67903585, 1482.5145193 ,
#         416.37355387,  290.98048434, 1068.92688103, 1363.65807707,
#         782.56221585,  133.38846435,  371.52291477,  803.325917  ,
#        1735.15213964, 1912.86929868, 2668.02261715, 1208.40720522,
#        1692.64491912, 1299.9754261 , 2058.66231904, 2045.35948499,
#         729.96663283, 1576.96282549, 1646.85939432,  290.98048434,
#         517.62371717,  346.00409062,  947.59245344,  295.22077608,
#         908.32059657,  337.32246567,  612.5147108 ,  623.31687405,
#        1739.73888443, 1200.57715812,  425.05131633, 1053.98019085,
#         624.69421379, 2122.9873515 ,  184.86254202, 1286.09582347,
#         705.46074291,  994.15547022,  702.41557973, 1171.39613601,
#        1454.15510667, 1274.76948231, 1000.45898682, 1245.65683432,
#         463.39274652, 1757.79287713, 1228.62518779,  493.56264975,
#         813.27029066, 1692.45574401,  528.3060519 , 1581.41494436,
#         167.15714155, 1878.88182262,  482.0448703 , 1722.06048142,
#        1226.59617787,  706.13433723,  706.1299642 , 1482.31081716,
#         655.39843894,  473.30284129,  490.50650409, 1245.15099335,
#         813.27029066,  958.98470382,  301.00534453, 1385.92442657,
#        1006.52045485,  493.56264975,  767.21999717, 1088.7287226 ,
#        1127.1100145 ,  343.44737258, 1089.55046506,  437.72465051,
#        2059.78371605,  572.42378622,  917.22300321, 1385.4638367 ,
#         485.23878323,  539.22536164, 1588.99173438])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample= pd.read_csv('./data/sample_submission.csv')
sample.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample['id'] = X_test_scaled.index
sample['Price_euros'] = y_predict_cat_plus.round(2)

# %%
sample
# Out:
#        id  Price_euros
# 0     181      2133.40
# 1     708       810.68
# 2     862       344.84
# 3    1064      1464.69
# 4     702      1158.64
# ..    ...          ...
# 386  1281       917.22
# 387   524      1385.46
# 388  1015       485.24
# 389  1236       539.23
# 390  1036      1588.99
#
# [391 rows x 2 columns]

# %%
sample.to_csv('./data/submission_cat_2.csv',index=False)

# %%
chequeator(sample)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 chequeator(sample)
#
# Cell In[100], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined
