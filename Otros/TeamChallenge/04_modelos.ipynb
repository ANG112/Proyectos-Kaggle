# %% [markdown]
# # Comparación con test

# %% [markdown]
# # Carga de librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from pprint import pprint

import warnings
warnings.filterwarnings('ignore')
pd.option_context('mode.use_inf_as_na', True)


import joblib
import os

from sklearn.decomposition import PCA


from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRFRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Cargo datos train

# %%
df_train = pd.read_csv('./data/df_final_precios_ordenadores.csv', index_col=0)
df_train.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'OpSys', 'Weight',
#        'Price_euros', 'Gpu Type', 'Resolution_disc', 'Family_disc',
#        'Clock_speed_disc', 'Modelo_procesador_disc', 'Gpu_Brand_disc',
#        'GPU_model_disc', 'storage_type_disc'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (912, 15)

# %%
df_train.head(8)
# Out:
#       Company            TypeName  Inches  Ram       OpSys  Weight  \
# id
# 268      Dell            Notebook    15.6    8  Windows 10    2.36
# 347      Asus            Notebook    15.6    4  Windows 10    2.00
# 353   Toshiba            Notebook    13.3    8   Windows 7    1.20
# 578      Dell              Gaming    15.6   16  Windows 10    4.42
# 42       Dell           Ultrabook    12.5    8   Windows 7    1.26
# 867      Asus  2 in 1 Convertible    15.6   12  Windows 10    2.26
# 1136     Asus            Notebook    15.6    4       Linux    2.00
# 609       MSI              Gaming    15.6    8  Windows 10    2.40
#
#       Price_euros   Gpu Type  Resolution_disc  Family_disc  Clock_speed_disc  \
# id
# 268        749.00  Dedicated                0            3                 3
# 347        449.00    Unknown                0            0                 0
# 353       1460.00    Unknown                2            2                 2
# 578       2868.99  Dedicated                6            3                 4
# 42        1713.37    Unknown                2            2                 1
# 867       1099.00  Dedicated                2            3                 3
# 1136       415.00    Unknown                2            1                 0
# 609       1142.80  Dedicated                2            3                 4
#
#       Modelo_procesador_disc  Gpu_Brand_disc  GPU_model_disc  \
# id
# 268                        3               0               1
# 347                        0               1               0
# 353                        2               1               2
# 578                        4               2               7
# 42                         3               1               2
# 867                        3               2               2
# 1136                       0               1               2
# 609                        4               2               2
#
#       storage_type_disc
# id
# 268                   1
# 347                   1
# 353                   3
# 578                   3
# 42                    3
# 867                   3
# 1136                  3
# 609                   3

# %% [markdown]
# # Cargo datos test

# %%
df_test = pd.read_csv('./data/df_test_disc_precios_ordenadores.csv',index_col=0)
df_test.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'OpSys', 'Weight',
#        'Resolution_disc', 'Family_disc', 'Clock_speed_disc',
#        'Modelo_procesador_disc', 'Gpu Type', 'Gpu_Brand_disc',
#        'GPU_model_disc', 'storage_type_disc'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (391, 14)

# %%
df_test.head(8)
# Out:
#      Company            TypeName  Inches  Ram       OpSys  Weight  \
# id
# 181       HP           Ultrabook    13.3   16  Windows 10    1.30
# 708     Acer            Notebook    15.6    8  Windows 10    2.20
# 862     Acer            Notebook    15.6    4       Linux    2.40
# 1064      HP            Notebook    14.0    8   Windows 7    1.43
# 702       HP            Notebook    13.3    8  Windows 10    1.34
# 585     Dell  2 in 1 Convertible    15.6   16  Windows 10    2.00
# 195    Razer              Gaming    14.0   16  Windows 10    1.95
# 463     Asus            Notebook    15.6    4       Linux    2.10
#
#       Resolution_disc  Family_disc  Clock_speed_disc  Modelo_procesador_disc  \
# id
# 181               6.0          3.0               3.0                     3.0
# 708               0.0          2.0               3.0                     0.0
# 862               0.0          1.0               0.0                     0.0
# 1064              2.0          2.0               2.0                     2.0
# 702               2.0          2.0               1.0                     1.0
# 585               2.0          3.0               2.0                     2.0
# 195               2.0          3.0               4.0                     4.0
# 463               2.0          2.0               1.0                     1.0
#
#        Gpu Type  Gpu_Brand_disc  GPU_model_disc  storage_type_disc
# id
# 181     Unknown             1.0             2.0                  3
# 708   Dedicated             0.0             2.0                  3
# 862     Unknown             1.0             2.0                  1
# 1064    Unknown             1.0             2.0                  3
# 702     Unknown             1.0             2.0                  3
# 585     Unknown             1.0             2.0                  3
# 195   Dedicated             2.0             4.0                  3
# 463   Dedicated             2.0             2.0                  1

# %% [markdown]
# Elimino la columna target Price_euros

# %%
X_train = df_train.drop(columns='Price_euros')
y_train = df_train['Price_euros']

# %%
features_list = X_train.columns.tolist()

df_test = df_test[features_list]

# %%
X_test = df_test

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
# Out:
# Las columnas son las mismas y están en el mismo orden: True

# %% [markdown]
# ## Cargo el modelo entrenado

# %%
model_path = os.path.join('models', 'rf_model_grid.pkl')
rf_model_grid = joblib.load(model_path)

# %% [markdown]
# ## Comparo contra test

# %%
features_cat = X_train.select_dtypes(include='object').columns.tolist()

X_train = pd.get_dummies(X_train, features_cat, dtype=int)
X_test = pd.get_dummies(X_test,features_cat,dtype=int)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 268 to 1179
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Inches                       912 non-null    float64
#  1   Ram                          912 non-null    int64
#  2   Weight                       912 non-null    float64
#  3   Resolution_disc              912 non-null    int64
#  4   Family_disc                  912 non-null    int64
#  5   Clock_speed_disc             912 non-null    int64
#  6   Modelo_procesador_disc       912 non-null    int64
#  7   Gpu_Brand_disc               912 non-null    int64
#  8   GPU_model_disc               912 non-null    int64
#  9   storage_type_disc            912 non-null    int64
#  10  Company_Acer                 912 non-null    int32
#  11  Company_Apple                912 non-null    int32
#  12  Company_Asus                 912 non-null    int32
#  13  Company_Chuwi                912 non-null    int32
#  14  Company_Dell                 912 non-null    int32
#  15  Company_Fujitsu              912 non-null    int32
#  16  Company_Google               912 non-null    int32
#  17  Company_HP                   912 non-null    int32
#  18  Company_Huawei               912 non-null    int32
#  19  Company_LG                   912 non-null    int32
#  20  Company_Lenovo               912 non-null    int32
#  21  Company_MSI                  912 non-null    int32
#  22  Company_Mediacom             912 non-null    int32
#  23  Company_Microsoft            912 non-null    int32
#  24  Company_Razer                912 non-null    int32
#  25  Company_Samsung              912 non-null    int32
#  26  Company_Toshiba              912 non-null    int32
#  27  Company_Vero                 912 non-null    int32
#  28  Company_Xiaomi               912 non-null    int32
#  29  TypeName_2 in 1 Convertible  912 non-null    int32
#  30  TypeName_Gaming              912 non-null    int32
#  31  TypeName_Netbook             912 non-null    int32
#  32  TypeName_Notebook            912 non-null    int32
#  33  TypeName_Ultrabook           912 non-null    int32
#  34  TypeName_Workstation         912 non-null    int32
#  35  OpSys_Android                912 non-null    int32
#  36  OpSys_Chrome OS              912 non-null    int32
#  37  OpSys_Linux                  912 non-null    int32
#  38  OpSys_Mac OS X               912 non-null    int32
#  39  OpSys_No OS                  912 non-null    int32
#  40  OpSys_Windows 10             912 non-null    int32
#  41  OpSys_Windows 10 S           912 non-null    int32
#  42  OpSys_Windows 7              912 non-null    int32
#  43  OpSys_macOS                  912 non-null    int32
#  44  Gpu Type_Dedicated           912 non-null    int32
#  45  Gpu Type_Unknown             912 non-null    int32
# dtypes: float64(2), int32(36), int64(8)
# memory usage: 206.6 KB

# %%
X_train.shape
# Out:
# (912, 46)

# %%
X_test.shape
# Out:
# (391, 43)

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
if son_iguales == True:
    print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
else:
    col_diferentes = set(X_train)-set(X_test)
    print(col_diferentes)
# Out:
# {'OpSys_Android', 'Company_Fujitsu', 'Company_Mediacom'}

# %%
# Alineo las columnas añadiendo las faltantes con valor cero.
X_train, X_test = X_train.align(X_test, join='outer', axis=1, fill_value=0)

# %%
# Comprobar si las columnas de X_train y X_test son las mismas y están en el mismo orden
son_iguales = list(X_train.columns) == list(X_test.columns)

# Imprimir el resultado
if son_iguales == True:
    print("Las columnas son las mismas y están en el mismo orden:", son_iguales)
else:
    col_diferentes = set(X_train)-set(X_test)
    print(col_diferentes)
# Out:
# Las columnas son las mismas y están en el mismo orden: True

# %%
X_train.columns
# Out:
# Index(['Clock_speed_disc', 'Company_Acer', 'Company_Apple', 'Company_Asus',
#        'Company_Chuwi', 'Company_Dell', 'Company_Fujitsu', 'Company_Google',
#        'Company_HP', 'Company_Huawei', 'Company_LG', 'Company_Lenovo',
#        'Company_MSI', 'Company_Mediacom', 'Company_Microsoft', 'Company_Razer',
#        'Company_Samsung', 'Company_Toshiba', 'Company_Vero', 'Company_Xiaomi',
#        'Family_disc', 'GPU_model_disc', 'Gpu Type_Dedicated',
#        'Gpu Type_Unknown', 'Gpu_Brand_disc', 'Inches',
#        'Modelo_procesador_disc', 'OpSys_Android', 'OpSys_Chrome OS',
#        'OpSys_Linux', 'OpSys_Mac OS X', 'OpSys_No OS', 'OpSys_Windows 10',
#        'OpSys_Windows 10 S', 'OpSys_Windows 7', 'OpSys_macOS', 'Ram',
#        'Resolution_disc', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming',
#        'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook',
#        'TypeName_Workstation', 'Weight', 'storage_type_disc'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['Clock_speed_disc', 'Company_Acer', 'Company_Apple', 'Company_Asus',
#        'Company_Chuwi', 'Company_Dell', 'Company_Fujitsu', 'Company_Google',
#        'Company_HP', 'Company_Huawei', 'Company_LG', 'Company_Lenovo',
#        'Company_MSI', 'Company_Mediacom', 'Company_Microsoft', 'Company_Razer',
#        'Company_Samsung', 'Company_Toshiba', 'Company_Vero', 'Company_Xiaomi',
#        'Family_disc', 'GPU_model_disc', 'Gpu Type_Dedicated',
#        'Gpu Type_Unknown', 'Gpu_Brand_disc', 'Inches',
#        'Modelo_procesador_disc', 'OpSys_Android', 'OpSys_Chrome OS',
#        'OpSys_Linux', 'OpSys_Mac OS X', 'OpSys_No OS', 'OpSys_Windows 10',
#        'OpSys_Windows 10 S', 'OpSys_Windows 7', 'OpSys_macOS', 'Ram',
#        'Resolution_disc', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming',
#        'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook',
#        'TypeName_Workstation', 'Weight', 'storage_type_disc'],
#       dtype='object')

# %% [markdown]
# Entiendo que tengo que tener en cuenta la selección de features con las que he entrenado el modelo de rf_model

# %%
# Ahora paso las columnas con las que he entrenado el modelo
features_sfs = ['Inches', 'Ram', 'Weight', 'Family_disc', 'Clock_speed_disc',
 'Modelo_procesador_disc', 'GPU_model_disc', 'storage_type_disc',
 'Company_Asus', 'Company_Dell', 'Company_Lenovo', 'Company_Razer',
 'Company_Xiaomi', 'TypeName_Workstation', 'OpSys_macOS']

# %%
X_train_model = X_train[features_sfs]
X_test_model = X_test[features_sfs]

# %%
y_predict = rf_model_grid.predict(X_test_model)
y_predict
# Out:
# array([1792.19915,  899.4896 ,  429.2343 , 1348.5721 , 1439.81255,
#        1321.9152 , 2832.7526 ,  624.41665, 2107.2617 , 1618.46965,
#        1475.9937 ,  575.79495,  286.3873 ,  640.2425 ,  432.09015,
#        1581.94995,  326.47   , 1871.853  , 1469.523  , 1482.2051 ,
#        1652.9441 , 1284.35315, 1676.9803 , 1515.67075, 1782.79495,
#         361.436  ,  883.92175,  303.33885, 1105.0398 ,  489.2124 ,
#        1019.18405, 1245.3115 , 1958.84235,  409.28035,  665.3094 ,
#        1541.7269 ,  761.7175 ,  773.17865, 3098.8957 ,  767.2922 ,
#         637.0873 ,  982.8262 , 1233.1565 , 1989.5724 ,  818.2008 ,
#        1693.61255,  586.6361 , 2988.7479 ,  320.79   , 1469.9422 ,
#        1199.11475,  934.5227 ,  864.19835,  359.9109 , 1150.37   ,
#         762.65265,  892.9655 ,  243.472  , 1474.20235, 1090.14735,
#        1297.61185, 1405.82975,  594.3686 , 1141.2954 , 1500.34435,
#        1454.36225,  535.7612 , 2713.75305,  516.19225, 2250.37165,
#         894.23785, 2306.99185, 1935.97225, 1071.30365, 1408.15435,
#        1218.4631 , 1042.29385,  486.9908 , 1216.4193 , 1059.49605,
#         310.5935 , 1907.651  , 1444.0787 ,  904.15145, 1333.733  ,
#        1714.7932 , 2250.37165,  495.4047 , 2119.67125,  489.6291 ,
#         684.28175,  429.2343 , 1090.14735,  835.08165, 1673.5935 ,
#         520.48975, 1839.0422 ,  973.84525,  971.0517 ,  772.51185,
#         517.7614 ,  374.25485, 1312.4235 ,  852.68705,  826.63145,
#        2153.0372 , 1934.2398 , 1652.9441 ,  756.03125,  325.3901 ,
#         929.2942 , 1272.48815,  640.0422 ,  294.403  ,  304.26   ,
#         780.5618 , 1490.52075, 1851.8211 , 1925.92065, 1180.18835,
#        1680.29755, 1207.91115, 2336.21855, 1914.9987 ,  842.0672 ,
#        1552.10835, 1617.26035,  325.3901 ,  585.3995 ,  340.5279 ,
#         864.19835,  344.1804 , 1008.9837 ,  326.4325 ,  677.19095,
#         774.31095, 1737.38885, 1224.12075,  386.0897 , 1035.7306 ,
#         677.19095, 2150.7569 ,  265.934  , 1677.63225,  548.747  ,
#         944.32635,  681.4155 , 1285.32075, 1351.27895, 1425.3773 ,
#        1045.2198 , 1261.0105 ,  486.9908 , 1739.41265, 1321.63   ,
#         461.76575,  851.80425, 1611.28395,  537.41355, 1680.5381 ,
#         236.803  , 2150.7569 ,  507.80665, 1378.83075, 1409.7918 ,
#         848.1456 ,  731.62475, 1370.7596 ,  826.1226 ,  620.5175 ,
#         492.6303 , 1055.7864 ,  851.80425,  775.31765,  329.4107 ,
#        1391.87805, 1008.9837 ,  461.76575,  916.75325, 1169.6388 ,
#        1159.17295,  344.1804 , 1167.805  ,  296.735  , 1907.25915,
#         488.5146 , 1191.30975, 1429.4128 ,  607.8571 ,  564.2361 ,
#        1561.47805])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample = pd.read_csv('./data/sample_submission.csv')
sample.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample['id'] = X_test.index
sample['Price_euros'] = y_predict.round(2)

# %%
sample
# Out:
#        id  Price_euros
# 0     181      1792.20
# 1     708       899.49
# 2     862       429.23
# 3    1064      1348.57
# 4     702      1439.81
# ..    ...          ...
# 386  1281      1191.31
# 387   524      1429.41
# 388  1015       607.86
# 389  1236       564.24
# 390  1036      1561.48
#
# [391 rows x 2 columns]

# %%
sample.to_csv('./data/submission.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 chequeator(sample)
#
# Cell In[31], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined

# %% [markdown]
# _____

# %% [markdown]
# He conseguido sacar la optimización del GBR

# %%
# Cargo el modelo entrenado
model_path = os.path.join('models', 'gbr_grid.pkl')
gbr_grid = joblib.load(model_path)

# %%
features_selector = ['Inches', 'Ram', 'Weight', 'Resolution_disc', 'Family_disc',
       'Clock_speed_disc', 'Modelo_procesador_disc', 'Gpu_Brand_disc',
       'GPU_model_disc', 'storage_type_disc', 'Company_Asus',
       'Company_Dell', 'Company_HP', 'Company_Lenovo', 'Company_MSI',
       'Company_Razer', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming',
       'TypeName_Notebook', 'TypeName_Workstation', 'OpSys_Windows 10',
       'OpSys_Windows 7', 'Gpu Type_Unknown']

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 268 to 1179
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clock_speed_disc             912 non-null    int64
#  1   Company_Acer                 912 non-null    int32
#  2   Company_Apple                912 non-null    int32
#  3   Company_Asus                 912 non-null    int32
#  4   Company_Chuwi                912 non-null    int32
#  5   Company_Dell                 912 non-null    int32
#  6   Company_Fujitsu              912 non-null    int32
#  7   Company_Google               912 non-null    int32
#  8   Company_HP                   912 non-null    int32
#  9   Company_Huawei               912 non-null    int32
#  10  Company_LG                   912 non-null    int32
#  11  Company_Lenovo               912 non-null    int32
#  12  Company_MSI                  912 non-null    int32
#  13  Company_Mediacom             912 non-null    int32
#  14  Company_Microsoft            912 non-null    int32
#  15  Company_Razer                912 non-null    int32
#  16  Company_Samsung              912 non-null    int32
#  17  Company_Toshiba              912 non-null    int32
#  18  Company_Vero                 912 non-null    int32
#  19  Company_Xiaomi               912 non-null    int32
#  20  Family_disc                  912 non-null    int64
#  21  GPU_model_disc               912 non-null    int64
#  22  Gpu Type_Dedicated           912 non-null    int32
#  23  Gpu Type_Unknown             912 non-null    int32
#  24  Gpu_Brand_disc               912 non-null    int64
#  25  Inches                       912 non-null    float64
#  26  Modelo_procesador_disc       912 non-null    int64
#  27  OpSys_Android                912 non-null    int32
#  28  OpSys_Chrome OS              912 non-null    int32
#  29  OpSys_Linux                  912 non-null    int32
#  30  OpSys_Mac OS X               912 non-null    int32
#  31  OpSys_No OS                  912 non-null    int32
#  32  OpSys_Windows 10             912 non-null    int32
#  33  OpSys_Windows 10 S           912 non-null    int32
#  34  OpSys_Windows 7              912 non-null    int32
#  35  OpSys_macOS                  912 non-null    int32
#  36  Ram                          912 non-null    int64
#  37  Resolution_disc              912 non-null    int64
#  38  TypeName_2 in 1 Convertible  912 non-null    int32
#  39  TypeName_Gaming              912 non-null    int32
#  40  TypeName_Netbook             912 non-null    int32
#  41  TypeName_Notebook            912 non-null    int32
#  42  TypeName_Ultrabook           912 non-null    int32
#  43  TypeName_Workstation         912 non-null    int32
#  44  Weight                       912 non-null    float64
#  45  storage_type_disc            912 non-null    int64
# dtypes: float64(2), int32(36), int64(8)
# memory usage: 206.6 KB

# %% [markdown]
# Tengo que escalar las variables

# %%
features_scaled = X_train.select_dtypes(include=(['int','float'])).columns.tolist()

print(features_scaled)
scaler = StandardScaler()

temp_x_train = scaler.fit_transform(X_train[features_scaled])
X_train_scaled = X_train.copy()
X_train_scaled[features_scaled] = temp_x_train


temp_x_test = scaler.transform(X_test[features_scaled])
X_test_scaled = X_test.copy()
X_test_scaled[features_scaled] = temp_x_test
# Out:
# ['Clock_speed_disc', 'Company_Acer', 'Company_Apple', 'Company_Asus', 'Company_Chuwi', 'Company_Dell', 'Company_Fujitsu', 'Company_Google', 'Company_HP', 'Company_Huawei', 'Company_LG', 'Company_Lenovo', 'Company_MSI', 'Company_Mediacom', 'Company_Microsoft', 'Company_Razer', 'Company_Samsung', 'Company_Toshiba', 'Company_Vero', 'Company_Xiaomi', 'Family_disc', 'GPU_model_disc', 'Gpu Type_Dedicated', 'Gpu Type_Unknown', 'Gpu_Brand_disc', 'Inches', 'Modelo_procesador_disc', 'OpSys_Android', 'OpSys_Chrome OS', 'OpSys_Linux', 'OpSys_Mac OS X', 'OpSys_No OS', 'OpSys_Windows 10', 'OpSys_Windows 10 S', 'OpSys_Windows 7', 'OpSys_macOS', 'Ram', 'Resolution_disc', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'Weight', 'storage_type_disc']

# %%
X_train_scaled
# Out:
#       Clock_speed_disc  Company_Acer  Company_Apple  Company_Asus  \
# id
# 268           0.731107     -0.299342       -0.13782     -0.366508
# 347          -1.239641     -0.299342       -0.13782      2.728451
# 353           0.074191     -0.299342       -0.13782     -0.366508
# 578           1.388023     -0.299342       -0.13782     -0.366508
# 42           -0.582725     -0.299342       -0.13782     -0.366508
# ...                ...           ...            ...           ...
# 89           -0.582725      3.340659       -0.13782     -0.366508
# 716           0.074191     -0.299342       -0.13782     -0.366508
# 517          -1.239641      3.340659       -0.13782     -0.366508
# 891           1.388023     -0.299342       -0.13782     -0.366508
# 1179          0.731107     -0.299342       -0.13782     -0.366508
#
#       Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# id
# 268       -0.046881      1.845480        -0.057448       -0.046881
# 347       -0.046881     -0.541864        -0.057448       -0.046881
# 353       -0.046881     -0.541864        -0.057448       -0.046881
# 578       -0.046881      1.845480        -0.057448       -0.046881
# 42        -0.046881      1.845480        -0.057448       -0.046881
# ...             ...           ...              ...             ...
# 89        -0.046881     -0.541864        -0.057448       -0.046881
# 716       -0.046881     -0.541864        -0.057448       -0.046881
# 517       -0.046881     -0.541864        -0.057448       -0.046881
# 891       -0.046881      1.845480        -0.057448       -0.046881
# 1179      -0.046881      1.845480        -0.057448       -0.046881
#
#       Company_HP  Company_Huawei  ...       Ram  Resolution_disc  \
# id                                ...
# 268    -0.511283       -0.033131  ... -0.038512        -1.239669
# 347    -0.511283       -0.033131  ... -0.855315        -1.239669
# 353    -0.511283       -0.033131  ... -0.038512         0.175322
# 578    -0.511283       -0.033131  ...  1.595095         3.005305
sample_gbr['id'] = X_test.index
sample_gbr['Price_euros'] = y_predict_gbr.round(2)

# %%
sample_gbr
# Out:
#        id  Price_euros
# 0     181      2075.38
# 1     708       720.28
# 2     862       353.94
# 3    1064      1511.77
# 4     702      1188.12
# ..    ...          ...
# 386  1281       972.62
# 387   524      1498.10
# 388  1015       537.84
# 389  1236       520.59
# 390  1036      1751.38
#
# [391 rows x 2 columns]

# %%
sample_gbr.to_csv('./data/submission_gbr_2.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample_gbr)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 chequeator(sample_gbr)
#
# Cell In[48], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined

# %% [markdown]
# ___

# %% [markdown]
# Cargo modelo de RandomForest con todas las columnas

# %% [markdown]
# ---

# %% [markdown]
# Pruebo con PCA (Análisis de Componenetes Principales)

# %%
pca_cl = PCA()

pca_cl.fit(X_train_scaled)

X_train_pca = pca_cl.transform(X_train_scaled)

# %%
X_train_pca.shape
# Out:
# (912, 46)

# %%
df_pca = pd.DataFrame(
    data = pca_cl.components_,
    columns=X_train_scaled.columns,
    index=[f'PC{n}' for n in range(1,X_train_scaled.shape[1]+1)]
)

df_pca
# Out:
#       Clock_speed_disc  Company_Acer  Company_Apple  Company_Asus  \
# PC1       2.983415e-01     -0.062671       0.011288      0.028979
# PC2       9.120145e-02     -0.090860       0.271677     -0.064367
# PC3       1.456617e-02      0.074879       0.430349     -0.026259
# PC4      -1.553111e-02     -0.015035      -0.219545      0.019342
# PC5       2.038473e-02      0.245590      -0.010182      0.206459
# PC6       6.280354e-02     -0.082460      -0.208279     -0.203098
# PC7       8.925407e-02      0.150241      -0.233448     -0.098284
# PC8      -5.959707e-02     -0.028594      -0.001686      0.057050
# PC9       8.624583e-03     -0.022767       0.102067     -0.012066
# PC10     -2.707084e-02     -0.241909      -0.022222      0.047758
# PC11     -1.590838e-02      0.191156       0.096476     -0.412190
# PC12     -6.751472e-02     -0.201971      -0.036967      0.625385
# PC13     -3.165726e-02     -0.345895      -0.056881     -0.230254


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 8))
ax.plot(
    np.arange(len(X_train_scaled.columns)) + 1,
    prop_varianza_acum,
    marker = 'o'
)

for x, y in zip(np.arange(len(X_train_scaled.columns)) + 1, prop_varianza_acum):
    label = round(y, 2)
    ax.annotate(
        label,
        (x,y),
        textcoords="offset points",
        xytext=(0,10),
        ha='center'
    )
    
ax.set_ylim(0, 1.1)
ax.set_xticks(np.arange(pca_cl.n_components_) + 1)
ax.set_title('Porcentaje de varianza explicada acumulada')
ax.set_xlabel('Componente principal')
ax.set_ylabel('Por. varianza acumulada');
# Out:
# ------------------------------------------
# Porcentaje de varianza explicada acumulada
# ------------------------------------------
# [0.14184893 0.22173761 0.27062513 0.31208798 0.35030828 0.38757551
#  0.42197237 0.45491365 0.48313766 0.51010866 0.53587583 0.56024225
#  0.58400393 0.60728883 0.63040487 0.65315167 0.67552382 0.69778028
#  0.71985286 0.74173713 0.76353756 0.78532948 0.80652658 0.82697047
#  0.84614083 0.86400527 0.8810148  0.89714612 0.91212852 0.92572542
#  0.93752545 0.94910394 0.96007847 0.96923935 0.97635991 0.98268779
#  0.98869996 0.99310918 0.99598144 0.99810993 1.         1.
#  1.         1.         1.         1.        ]

# %%
rf_pca = RandomForestRegressor (max_depth=5, random_state=42) 
scores_pca = []
for num_PCs in range(29,38):
    print(f"Probando con {num_PCs} componentes:", sep = " ")
    X_train_pca_reduced = X_train_pca[:,:num_PCs]# Array de numpy. Al estar ordenadas me quedo con las que quiero.
    score_pca = np.mean(cross_val_score(rf_pca, X_train_pca_reduced, y_train, cv = 5, scoring = "neg_mean_absolute_error"))
    print(score_pca)
    scores_pca.append(score_pca)
# Out:
# Probando con 29 componentes:
# -201.06046491912412
# Probando con 30 componentes:
# -200.52090216525477
# Probando con 31 componentes:
# -200.92344806286286
# Probando con 32 componentes:
# -200.5574384569627
# Probando con 33 componentes:
# -201.55080027242406
# Probando con 34 componentes:
# -198.9058158839715
# Probando con 35 componentes:
# -198.3893644308111
# Probando con 36 componentes:
# -198.46659918494052
# Probando con 37 componentes:
# -197.87237356945775

# %%
rf_pca = RandomForestRegressor (max_depth=5, random_state=42) 
scores_pca = []
for num_PCs in range(38,46):
    print(f"Probando con {num_PCs} componentes:", sep = " ")
    X_train_pca_reduced = X_train_pca[:,:num_PCs]# Array de numpy. Al estar ordenadas me quedo con las que quiero.
    score_pca = np.mean(cross_val_score(rf_pca, X_train_pca_reduced, y_train, cv = 5, scoring = "neg_mean_absolute_error"))
    print(score_pca)
    scores_pca.append(score_pca)
# Out:
# Probando con 38 componentes:
# -196.22529335107453
# Probando con 39 componentes:
# -196.98553754516942
# Probando con 40 componentes:
# -196.87883573959718
# Probando con 41 componentes:
# -195.6867958931843
# Probando con 42 componentes:
# -196.04118831956694
# Probando con 43 componentes:
# -196.08917799299496
# Probando con 44 componentes:
# -195.99207253081607
# Probando con 45 componentes:
# -196.0277989861095

# %% [markdown]
# Pues aparentemente no mejor los otros modelos

# %% [markdown]
# ___

# %%
X_train_model=X_train_scaled

rf_model = RandomForestRegressor(max_depth=5, random_state=42)

param_grid = {
    'n_estimators': [100, 200, 300],
    'criterion': ['absolute_error'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}

rf_model_grid_all = GridSearchCV(estimator=rf_model,
							   param_grid=param_grid,
							   scoring='neg_mean_absolute_error',
							   cv=5,
							   n_jobs=-1)

rf_model_grid_all.fit(X_train_model, y_train)
best_model_clf = rf_model_grid_all.best_estimator_
best_params_clf = rf_model_grid_all.best_params_
best_score_clf = rf_model_grid_all.best_score_

print(f'Best Parameters for Classification: {best_params_clf}')
print(f'Best Score for Classification: {best_score_clf}')
# Out:
# Best Parameters for Classification: {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best Score for Classification: -159.8522430532037

# %%
y_predict_rf_all = rf_model_grid_all.predict(X_test_scaled)
y_predict_rf_all
# Out:
# array([2097.07828333,  740.35623333,  397.61783333, 1458.3034    ,
#        1100.12833333, 1221.81871667, 2973.1058    ,  658.18745   ,
#        2159.97953333, 2214.61851667, 1381.603     ,  636.74441667,
#         267.43661667,  624.57918333,  432.9558    , 1599.60426667,
#         384.51246667, 2038.44195   , 1723.19921667, 1498.53165   ,
#        1705.31596667, 1325.24106667, 1652.71963333, 1439.8924    ,
#        1650.76896667,  340.42475   ,  898.6431    ,  339.20793333,
#        1185.10893333,  607.90096667,  980.00543333, 1186.0575    ,
#        2042.42213333,  400.48653333,  673.34513333, 1671.33466667,
#         764.91738333,  667.49046667, 3062.40526667,  719.22916667,
#         745.64666667, 1040.76546667, 1108.63458333, 1887.3134    ,
#         936.02108333, 1626.56706667,  506.07373333, 2973.53      ,
#         359.10203333, 1312.89678333, 1122.8505    , 1049.0373    ,
#         888.63806667,  301.223     , 1141.89886667,  684.86843333,
#         838.4399    ,  231.37781667, 1431.99891667, 1103.39468333,
#        1393.2216    , 1225.90418333,  648.67523333, 1331.74385   ,
#        1281.51523333, 1446.41986667,  601.32241667, 2587.21411667,
#         541.53023333, 2030.97833333,  942.73495   , 2400.94855   ,
#        1958.09216667, 1022.89428333, 1447.92898333, 1215.47335   ,
#         951.57531667,  474.7814    , 1109.93261667, 1129.95088333,
#         288.55833333, 1545.20675   , 1392.05151667,  889.6566    ,
#        1258.98713333, 1795.65553333, 2028.45833333,  506.0065    ,
#        2054.0709    ,  455.1667    ,  756.12926667,  414.44003333,
#        1103.39468333, 1038.61556667, 1847.98368333,  495.77378333,
#        1939.49206667, 1114.73688333,  904.37486667,  608.09945   ,
#         553.56405   ,  451.78506667, 1378.13791667, 1121.57776667,
#         915.5935    ,  807.09195   , 1117.18295   ,  813.88691667,
#        1190.62658333, 1156.01348333, 1332.2032    ,  935.33463333,
#         311.31615   ,  551.37558333,  999.33441667, 1438.65923333,
#         947.84566667, 1165.01508333,  600.66385   , 1531.78526667,
#         450.32886667, 1267.80753333,  907.89896667, 1333.8       ,
#         302.022     , 1455.686     , 2550.4826    , 2035.38673333,
#        1887.3134    ,  962.78521667, 1075.1176    , 1325.45268333,
#         468.29553333, 1592.47383333,  551.44413333,  661.05773333,
#         291.20888333, 2066.00346667, 1412.23258333,  666.0094    ,
#         620.83556667,  380.2106    ,  888.63806667,  274.17918333,
#         893.31148333,  340.25451667,  650.52321667,  733.33288333,
#        1770.96095   , 1257.43548333,  376.84006667, 1174.93661667,
#         657.35301667, 2228.78903333,  266.4585    , 1554.74163333,
#         596.89005   , 1021.95336667,  724.74941667, 1220.58435   ,
#        1570.919     , 1356.35413333, 1097.16483333, 1274.69618333,
#         484.55595   , 1798.33586667, 1207.91893333,  516.46621667,
#         840.18095   , 1739.55666667,  489.19785   , 1681.911     ,
#         207.22766667, 2213.25751667,  501.71471667, 1606.3104    ,
#        1194.54218333,  635.3084    ,  720.77718333, 1443.78996667,
#         797.8301    ,  517.28821667,  472.40331667, 1079.59866667,
#         840.18095   ,  884.39213333,  313.54065   , 1407.92256667,
#        1140.06253333,  516.46621667,  766.69265   , 1129.71716667,
#        1158.92238333,  357.22695   , 1088.76641667,  349.637     ,
#        2172.54316667,  562.34435   , 1076.57105   , 1354.67423333,
#         442.36146667,  535.9627    , 1510.7203    ])

# %% [markdown]
# ## Cargo sample_submission

# %%
sample_rf_all = pd.read_csv('./data/sample_submission.csv')
sample_rf_all.head(8)
# Out:
#      id  Price_euros
# 0  1014       752.00
# 1   845       499.00
# 2  1151      1747.00
# 3  1265       245.00
# 4   573      1179.00
# 5   521       340.00
# 6   316       403.00
# 7   133      1545.64

# %%
sample_rf_all['id'] = X_test.index
sample_rf_all['Price_euros'] = y_predict_rf_all.round(2)

# %%
sample_rf_all
# Out:
#        id  Price_euros
# 0     181      2097.08
# 1     708       740.36
# 2     862       397.62
# 3    1064      1458.30
# 4     702      1100.13
# ..    ...          ...
# 386  1281      1076.57
# 387   524      1354.67
# 388  1015       442.36
# 389  1236       535.96
# 390  1036      1510.72
#
# [391 rows x 2 columns]

# %%
sample_rf_all.to_csv('./data/submission_rf_all.csv',index=False)

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(sample_rf_all)
# Out:
# You're ready to submit!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 chequeator(sample_rf_all)
#
# Cell In[73], line 21, in chequeator(df_to_submit)
#      19 if df_to_submit.id.all() == sample.id.all():
#      20     print("You're ready to submit!")
# ---> 21     submission.to_csv("submission.csv", index = False) #muy importante el index = False
#      22     urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")
#      23     img = Image.open("gfg.png")
#
# NameError: name 'submission' is not defined
